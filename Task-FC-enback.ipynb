# %%
import numpy as np
import pandas as pd
import os
import glob

import nilearn
from nilearn import datasets, plotting,signal # datasets: for fetching atlas
from nilearn.input_data import NiftiLabelsMasker
from nilearn.connectome import ConnectivityMeasure

from nilearn.glm.first_level import make_first_level_design_matrix

import matplotlib.pyplot as plt

os.chdir("/home/acamassa/ABCD/DDC/src/py_DDC")
from Compute_DDC import *
# Out:
# /home/acamassa/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/acamassa/anaconda3/lib/python3.9/site-packages/nilearn/input_data/__init__.py:23: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
import glob

os.chdir("/nadata/cnl/abcd/data/imaging/fmri/nback/interim/segmented/baseline/")
# os.chdir('/cnl/abcd/data/imaging/fmri/rsfmri/interim/segmented/baseline_depr/')
files = glob.glob("**/filt_fMRI_segmented**.csv", recursive=True)
ddc_dir='/cnl/abcd/data/imaging/fmri/nback/interim/DDC/'

# %%
error=[]

for f in files:
    
    for cond in ['2_back','0_back']:
        
        #subject
        sub_id=f.split('/')[0]
        run=f[-10:-4] 
        
        if not os.path.exists(ddc_dir + f.split("/")[0] + "/single_sessions/" + "subc_Reg_DDC_" + run + '_' + cond + '.csv'):
            print(f"{sub_id}, run:{run}")
            try:
                # load segmented data
                data=pd.read_csv(f)
                timeseries_all=np.asarray(data)


                #load events onset
                events = pd.read_table(f'/snl/abcd/raw-data/fmri/baseline/nback/{sub_id}/ses-baselineYear1Arm1/func/{sub_id}_ses-baselineYear1Arm1_task-nback_{run}_events.tsv')
                t_r = 0.8
                n_scans = len(timeseries_all)

                # make design matrix
                frame_times = np.arange(n_scans) * t_r
                design_matrix = make_first_level_design_matrix(frame_times, events, hrf_model = None)
                design_matrix = design_matrix.reset_index()

                # extract one condition
                string_cols = design_matrix.filter(regex=f'^{cond}')
                A = string_cols.sum(axis=1) 
                task = timeseries_all[A.astype('bool').astype('bool'), :]

                # compute DDC
                Cov, DDC, Reg_DDC, nl_DDC, qc_flag = compute_ddc(task, 0.8, "c")

                if not os.path.exists(ddc_dir + f.split("/")[0] + "/single_sessions/"):
                    print("making dir")
                    os.makedirs(ddc_dir + f.split("/")[0] + "/single_sessions/")


                pd.DataFrame(Cov).to_csv(
                ddc_dir + f.split("/")[0] + "/single_sessions/" + "subc_Cov_" + run + '_' + cond + '.csv' ,
                header=None,
                index=None,
                )
                pd.DataFrame(DDC).to_csv(
                    ddc_dir + f.split("/")[0] + "/single_sessions/" + "subc_DDC_"+ run + '_' + cond + '.csv',
                    header=None,
                    index=None,
                )
                pd.DataFrame(Reg_DDC).to_csv(
                    ddc_dir + f.split("/")[0] + "/single_sessions/" + "subc_Reg_DDC_" + run + '_' + cond + '.csv',
                    header=None,
                    index=None,
                )

                # compute fractional DDC and reg fract DDC
                FDDC, Reg_FDDC = compute_fddc(task, 0.8, 0.5)
                pd.DataFrame(FDDC).to_csv(
                    ddc_dir + f.split("/")[0] + "/single_sessions/" + "subc_FDDC_" + run + '_' + cond + '.csv',
                    header=None,
                    index=None,
                )
                pd.DataFrame(Reg_FDDC).to_csv(
                    ddc_dir
                    + f.split("/")[0]
                    + "/single_sessions/"
                    + "subc_Reg_FDDC_"
                    + run + '_' + cond + '.csv',
                    header=None,
                    index=None,
                )

                print(f"contition {cond} saved")
            except:
                error.append(f)
# Out:
# sub-NDARINVJ9D04KNJ, run:run-01
# sub-NDARINVJ9D04KNJ, run:run-01
# sub-NDARINVJ9D04KNJ, run:run-02
# sub-NDARINVJ9D04KNJ, run:run-02
# sub-NDARINVJCC8EVMK, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJCC8EVMK, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJCC8EVMK, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJCC8EVMK, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJCFMFR6E, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJCFMFR6E, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJCFMFR6E, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJCFMFR6E, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJDZ90ATC, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJDZ90ATC, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJDZ90ATC, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJDZ90ATC, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJE7AU0B9, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJE7AU0B9, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJE7AU0B9, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJE7AU0B9, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJFJL5WJL, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJFJL5WJL, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJFJL5WJL, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJFJL5WJL, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJGM06GHD, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJGM06GHD, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJGM06GHD, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJGM06GHD, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJGY9JJPW, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJGY9JJPW, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJGY9JJPW, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJGY9JJPW, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJH22CRH8, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJH22CRH8, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJH22CRH8, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJH22CRH8, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJHX361ZP, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJHX361ZP, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJHX361ZP, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJHX361ZP, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJJ2DNAR0, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJJ2DNAR0, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJJ2DNAR0, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJJ2DNAR0, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJJWR8W0W, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJJWR8W0W, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJJWR8W0W, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJJWR8W0W, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJKDWLHZU, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJKDWLHZU, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJKDWLHZU, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJKDWLHZU, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJKT4Z5GW, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJKT4Z5GW, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJKT4Z5GW, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJKT4Z5GW, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJM19UTB0, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJM19UTB0, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJM19UTB0, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJM19UTB0, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJP978MN3, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJP978MN3, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJP978MN3, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJP978MN3, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJR8B2Z56, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJR8B2Z56, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJR8B2Z56, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJR8B2Z56, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJRXPZU5X, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJRXPZU5X, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJRXPZU5X, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJRXPZU5X, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJRZMV890, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJRZMV890, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJRZMV890, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJRZMV890, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJT5AUAK8, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJT5AUAK8, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJT5AUAK8, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJT5AUAK8, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJTHY8P5B, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJTHY8P5B, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJTHY8P5B, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJTHY8P5B, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJTU3X2VF, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJTU3X2VF, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJTU3X2VF, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJTU3X2VF, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJU8R73PG, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJU8R73PG, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJU8R73PG, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJU8R73PG, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJVPFFH8R, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJVPFFH8R, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJVPFFH8R, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJVPFFH8R, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJX0PX7UM, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJX0PX7UM, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJX0PX7UM, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJX0PX7UM, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJX509T01, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJX509T01, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJX509T01, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJX509T01, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJXKV7NF7, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVJXKV7NF7, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVJXKV7NF7, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVJXKV7NF7, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK0870VPA, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVK0870VPA, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK0870VPA, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVK0870VPA, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK0N7MLA9, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVK0N7MLA9, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK0N7MLA9, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVK0N7MLA9, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK1WPW1EZ, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVK1WPW1EZ, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK1WPW1EZ, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVK1WPW1EZ, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK3FXPMNK, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVK3FXPMNK, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK3FXPMNK, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVK3FXPMNK, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK3K5DLKW, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVK3K5DLKW, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK3K5DLKW, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVK3K5DLKW, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK427BMWY, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVK427BMWY, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK427BMWY, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVK427BMWY, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK5MXZ6UG, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVK5MXZ6UG, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK5MXZ6UG, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVK5MXZ6UG, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK6HKNVP1, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVK6HKNVP1, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK6HKNVP1, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVK6HKNVP1, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK7B15B7Z, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVK7B15B7Z, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK7B15B7Z, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVK7B15B7Z, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK84182YD, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVK84182YD, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK84182YD, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVK84182YD, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK9E4206N, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVK9E4206N, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK9E4206N, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVK9E4206N, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK9GFBGJZ, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVK9GFBGJZ, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVK9GFBGJZ, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVK9GFBGJZ, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKAKFCN21, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKAKFCN21, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKAKFCN21, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKAKFCN21, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKB1LL4HJ, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKB1LL4HJ, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKB1LL4HJ, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKB1LL4HJ, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKBLYK9GE, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKBLYK9GE, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKBLYK9GE, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKBLYK9GE, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKCZZYZB5, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKCZZYZB5, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKCZZYZB5, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKCZZYZB5, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKD8JTUFA, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKD8JTUFA, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKD8JTUFA, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKD8JTUFA, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKEARFZ9N, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKEARFZ9N, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKEARFZ9N, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKEARFZ9N, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKEDNL754, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKEDNL754, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKEDNL754, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKEDNL754, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKFGPP88F, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKFGPP88F, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKFGPP88F, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKFGPP88F, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKFH14EDW, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKFH14EDW, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKFH14EDW, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKFH14EDW, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKGU77A38, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKGU77A38, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKGU77A38, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKGU77A38, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKHXDKCB7, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKHXDKCB7, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKHXDKCB7, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKHXDKCB7, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKJCKZPX0, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKJCKZPX0, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKJCKZPX0, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKJCKZPX0, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKJP5X4W9, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKJP5X4W9, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKJP5X4W9, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKJP5X4W9, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKK5BJGB6, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKK5BJGB6, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKK5BJGB6, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKK5BJGB6, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKN0URLJE, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKN0URLJE, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKN0URLJE, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKN0URLJE, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKPF9HV5P, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKPF9HV5P, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKPF9HV5P, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKPF9HV5P, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKR81E1T7, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKR81E1T7, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKR81E1T7, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKR81E1T7, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKRNZWREV, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKRNZWREV, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKRNZWREV, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKRNZWREV, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKT39B7XP, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKT39B7XP, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKT39B7XP, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKT39B7XP, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKTZCHRX8, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKTZCHRX8, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKTZCHRX8, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKTZCHRX8, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKUJ7WV09, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKUJ7WV09, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKUJ7WV09, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKUJ7WV09, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKVV9NU2R, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKVV9NU2R, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKVV9NU2R, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKVV9NU2R, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKVXP0RJF, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKVXP0RJF, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKVXP0RJF, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKVXP0RJF, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKW02LRCP, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKW02LRCP, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKW02LRCP, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKW02LRCP, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKY6C0Z8R, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKY6C0Z8R, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKY6C0Z8R, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKY6C0Z8R, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKYCN6AYE, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKYCN6AYE, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKYCN6AYE, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKYCN6AYE, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKZ9TH4UJ, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVKZ9TH4UJ, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVKZ9TH4UJ, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVKZ9TH4UJ, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL3DZEL4D, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVL3DZEL4D, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL3DZEL4D, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVL3DZEL4D, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL49379MF, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVL49379MF, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL49379MF, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVL49379MF, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL4F3ZTF3, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVL4F3ZTF3, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL4F3ZTF3, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVL4F3ZTF3, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL5GHARC8, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVL5GHARC8, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL5GHARC8, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVL5GHARC8, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL7XCKG7W, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVL7XCKG7W, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL7XCKG7W, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVL7XCKG7W, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL8EJK2VY, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVL8EJK2VY, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL8EJK2VY, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVL8EJK2VY, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL8PY2P4B, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVL8PY2P4B, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL8PY2P4B, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVL8PY2P4B, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL9XK6K7N, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVL9XK6K7N, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVL9XK6K7N, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVL9XK6K7N, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLBELG3A6, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLBELG3A6, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLBELG3A6, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLBELG3A6, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLC6CLU57, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLC6CLU57, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLC6CLU57, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLC6CLU57, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLDK00HZG, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLDK00HZG, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLDK00HZG, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLDK00HZG, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLEH6BPD5, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLEH6BPD5, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLEH6BPD5, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLEH6BPD5, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLF021MRZ, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLF021MRZ, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLF021MRZ, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLF021MRZ, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLGJH5VV9, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLGJH5VV9, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLGJH5VV9, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLGJH5VV9, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLH5M1C12, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLH5M1C12, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLH5M1C12, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLH5M1C12, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLH81TZYY, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLH81TZYY, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLH81TZYY, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLH81TZYY, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLH8GZ09D, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLH8GZ09D, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLH8GZ09D, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLH8GZ09D, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLHZWGFNU, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLHZWGFNU, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLHZWGFNU, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLHZWGFNU, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLJ8VU64E, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLJ8VU64E, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLJ8VU64E, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLJ8VU64E, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLK2ZABWM, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLK2ZABWM, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLK2ZABWM, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLK2ZABWM, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLLC8XX9N, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLLC8XX9N, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLLC8XX9N, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLLC8XX9N, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLLURBVRZ, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLLURBVRZ, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLLURBVRZ, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLLURBVRZ, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLM6JRR6C, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLM6JRR6C, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLM6JRR6C, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLM6JRR6C, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLNA2KYAP, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLNA2KYAP, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLNA2KYAP, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLNA2KYAP, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLNA4879N, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLNA4879N, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLNA4879N, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLNA4879N, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLPB8G89P, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLPB8G89P, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLPB8G89P, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLPB8G89P, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLTJFH518, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLTJFH518, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLTJFH518, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLTJFH518, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLTNAN0HU, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLTNAN0HU, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLTNAN0HU, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLTNAN0HU, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLVLGKC0B, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLVLGKC0B, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLVLGKC0B, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLVLGKC0B, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLX09YB8N, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLX09YB8N, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLX09YB8N, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLX09YB8N, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLX2BTC9B, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLX2BTC9B, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLX2BTC9B, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLX2BTC9B, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLXDEDXFV, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLXDEDXFV, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLXDEDXFV, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLXDEDXFV, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLXEAXZ7M, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVLXEAXZ7M, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVLXEAXZ7M, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVLXEAXZ7M, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM03FUB7G, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVM03FUB7G, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM03FUB7G, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVM03FUB7G, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM05MNA24, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVM05MNA24, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM05MNA24, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVM05MNA24, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM0DUMRDX, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVM0DUMRDX, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM0DUMRDX, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVM0DUMRDX, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM0L87M5X, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVM0L87M5X, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM0L87M5X, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVM0L87M5X, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM3BPA3ZR, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVM3BPA3ZR, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM3BPA3ZR, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVM3BPA3ZR, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM3VWCXNN, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVM3VWCXNN, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM3VWCXNN, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVM3VWCXNN, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM50LU9VD, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVM50LU9VD, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM50LU9VD, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVM50LU9VD, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM5GX1Z2W, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVM5GX1Z2W, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM5GX1Z2W, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVM5GX1Z2W, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM6LGY18K, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVM6LGY18K, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM6LGY18K, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVM6LGY18K, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM6LR22KX, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVM6LR22KX, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM6LR22KX, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVM6LR22KX, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM7T4Y22R, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVM7T4Y22R, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM7T4Y22R, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVM7T4Y22R, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVM8CDN9GH, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVM8CDN9GH, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMAFGTMLE, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMAFGTMLE, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMAFGTMLE, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMAFGTMLE, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMBWZMZ7V, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMBWZMZ7V, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMBWZMZ7V, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMBWZMZ7V, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMCTA6E68, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMCTA6E68, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMCTA6E68, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMCTA6E68, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMDX2NCNW, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMDX2NCNW, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMDX2NCNW, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMDX2NCNW, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMDY1W3Y0, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMDY1W3Y0, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMDY1W3Y0, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMDY1W3Y0, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMF4B9XWV, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMF4B9XWV, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMF4B9XWV, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMF4B9XWV, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMG9REUL8, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMG9REUL8, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMG9REUL8, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMG9REUL8, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMGH9KKCV, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMGH9KKCV, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMGH9KKCV, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMGH9KKCV, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMGX9TZCB, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMGX9TZCB, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMJ61WEFZ, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMJ61WEFZ, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMJ61WEFZ, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMJ61WEFZ, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMJB4F3FB, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMJB4F3FB, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMJB4F3FB, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMJB4F3FB, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMKC6DKGG, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMKC6DKGG, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMKC6DKGG, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMKC6DKGG, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMKNER6N9, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMKNER6N9, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMKNER6N9, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMKNER6N9, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMKPR1T1N, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMKPR1T1N, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMKPR1T1N, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMKPR1T1N, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMLDY2ZT2, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMLDY2ZT2, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMLDY2ZT2, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMLDY2ZT2, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMLFXUXUL, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMLFXUXUL, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMLFXUXUL, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMLFXUXUL, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMMPNAM6J, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMMPNAM6J, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMMPNAM6J, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMMPNAM6J, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMN4MAMYN, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMN4MAMYN, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMN4MAMYN, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMN4MAMYN, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMNJ9X217, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMNJ9X217, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMNJ9X217, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMNJ9X217, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMNL567Y1, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMNL567Y1, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMNL567Y1, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMNL567Y1, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMP6JFH4L, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMP6JFH4L, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMP6JFH4L, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMP6JFH4L, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMTJ6URWD, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMTJ6URWD, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMTJ6URWD, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMTJ6URWD, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMTYZ9AH4, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMTYZ9AH4, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMTYZ9AH4, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMTYZ9AH4, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMVT25ECP, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMVT25ECP, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMVT25ECP, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMVT25ECP, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMW03YLYP, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMW03YLYP, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMW03YLYP, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMW03YLYP, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMWY2AZNP, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMWY2AZNP, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMWY2AZNP, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMWY2AZNP, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMY1X0RAH, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMY1X0RAH, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMY1X0RAH, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMY1X0RAH, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMY85AAAM, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMY85AAAM, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMY85AAAM, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMY85AAAM, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMZ0E548E, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVMZ0E548E, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVMZ0E548E, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVMZ0E548E, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN160DMUM, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVN160DMUM, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN160DMUM, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVN160DMUM, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN29F40LG, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVN29F40LG, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN29F40LG, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVN29F40LG, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN2CM6UDZ, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVN2CM6UDZ, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN2CM6UDZ, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVN2CM6UDZ, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN4800E3M, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVN4800E3M, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN4800E3M, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVN4800E3M, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN4BPDTK4, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVN4BPDTK4, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN4BPDTK4, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVN4BPDTK4, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN58UMDJ3, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVN58UMDJ3, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN58UMDJ3, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVN58UMDJ3, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN5919504, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVN5919504, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN5919504, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVN5919504, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN5BG5LUD, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVN5BG5LUD, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN5BG5LUD, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVN5BG5LUD, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN8P9M0EX, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVN8P9M0EX, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN8P9M0EX, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVN8P9M0EX, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN9X5J0M6, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVN9X5J0M6, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVN9X5J0M6, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVN9X5J0M6, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVNB7DWNKK, run:run-01
# Cov is rank deficient!
# ...
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYCL4R17D, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYCL4R17D, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYCL4R17D, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYE99F6V6, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYE99F6V6, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYE99F6V6, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYE99F6V6, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYEJ0162B, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYEJ0162B, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYEJ0162B, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYEJ0162B, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYEMHGFJF, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYEMHGFJF, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYEMHGFJF, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYEMHGFJF, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYGBUZKCW, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYGBUZKCW, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYGBUZKCW, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYGBUZKCW, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYHAF0YYH, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYHAF0YYH, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYHAF0YYH, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYHAF0YYH, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYJG0V5F9, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYJG0V5F9, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYJG0V5F9, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYJG0V5F9, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYLNRHT83, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYLNRHT83, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYLNRHT83, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYLNRHT83, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYN4CXY1B, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYN4CXY1B, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYNCHCTAD, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYNCHCTAD, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYNCHCTAD, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYNCHCTAD, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYPRNYTTL, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYPRNYTTL, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYPRNYTTL, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYPRNYTTL, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYTVCUEA2, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYTVCUEA2, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYTVCUEA2, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYTVCUEA2, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYU20X3EV, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYU20X3EV, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYU20X3EV, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYU20X3EV, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYUXB5PRZ, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYUXB5PRZ, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYUXB5PRZ, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYUXB5PRZ, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYUZG9ZNP, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYUZG9ZNP, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYUZG9ZNP, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYUZG9ZNP, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYWEY5YL9, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYWEY5YL9, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYWEY5YL9, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYWEY5YL9, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYXATK265, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYXATK265, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYXATK265, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYXATK265, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYZ0U1DGC, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYZ0U1DGC, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYZ0U1DGC, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYZ0U1DGC, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYZFMM6MW, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVYZFMM6MW, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVYZFMM6MW, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVYZFMM6MW, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ0TL0G08, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZ0TL0G08, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ0TL0G08, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZ0TL0G08, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ1B2P1NH, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZ1B2P1NH, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ1B2P1NH, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZ1B2P1NH, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ1V6MUBA, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZ1V6MUBA, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ1V6MUBA, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZ1V6MUBA, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ1WUT8NP, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZ1WUT8NP, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ1WZW3KT, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZ1WZW3KT, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ1WZW3KT, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZ1WZW3KT, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ24E0KC2, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZ24E0KC2, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ2BXG0C8, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZ2BXG0C8, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ2BXG0C8, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZ2BXG0C8, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ2E8YJN2, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZ2E8YJN2, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ2E8YJN2, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZ2E8YJN2, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ4DPYEX3, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZ4DPYEX3, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ4DPYEX3, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZ4DPYEX3, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ547MN37, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZ547MN37, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ547MN37, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZ547MN37, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ6W66EFM, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZ6W66EFM, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ6W66EFM, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZ6W66EFM, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ9CR6U8L, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZ9CR6U8L, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZ9CR6U8L, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZ9CR6U8L, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZDHYHJKH, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZDHYHJKH, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZDHYHJKH, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZDHYHJKH, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZDLAWZZL, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZDLAWZZL, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZDLAWZZL, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZDLAWZZL, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZEAUYCZF, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZEAUYCZF, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZEAUYCZF, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZEAUYCZF, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZG4U8G7X, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZG4U8G7X, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZG4U8G7X, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZG4U8G7X, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZJ1WJ57J, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZJ1WJ57J, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZJ1WJ57J, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZJ1WJ57J, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZJV3HZEF, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZJV3HZEF, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZJV3HZEF, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZJV3HZEF, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZL6CFV5G, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZL6CFV5G, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZL6CFV5G, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZL6CFV5G, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZN9E45NT, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZN9E45NT, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZN9E45NT, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZN9E45NT, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZNW7Y6R1, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZNW7Y6R1, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZNW7Y6R1, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZNW7Y6R1, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZP06U57U, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZP06U57U, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZP06U57U, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZP06U57U, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZPE7604M, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZPE7604M, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZPE7604M, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZPE7604M, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZRKWPYJL, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZRKWPYJL, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZRKWPYJL, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZRKWPYJL, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZTTGYL51, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZTTGYL51, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZTTGYL51, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZTTGYL51, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZU422XFY, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZU422XFY, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZU422XFY, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZU422XFY, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZU8PLK49, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZU8PLK49, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZU8PLK49, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZU8PLK49, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZUGVEHNK, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZUGVEHNK, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZUGVEHNK, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZUGVEHNK, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZUXFF006, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZUXFF006, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZUXFF006, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZUXFF006, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZVK7PB78, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZVK7PB78, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZVK7PB78, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZVK7PB78, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZZ0348LF, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZZ0348LF, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZZ0348LF, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZZ0348LF, run:run-02
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZZPKBDAC, run:run-01
# Cov is rank deficient!
# making dir
# contition 2_back saved
# sub-NDARINVZZPKBDAC, run:run-01
# Cov is rank deficient!
# contition 0_back saved
# sub-NDARINVZZPKBDAC, run:run-02
# Cov is rank deficient!
# contition 2_back saved
# sub-NDARINVZZPKBDAC, run:run-02
# Cov is rank deficient!
# contition 0_back saved

# %%
import pandas as pd

data=pd.read_csv(files[0])

# %%
timeseries_all=np.asarray(data)
plt.figure(figsize = (15, 5))
plt.plot(timeseries_all)
plt.show()

# %%
sub_id=files[0].split('/')[0]
run=f[-10:-4]
confounds= pd.read_table(f'/snl/abcd/raw-data/fmri/baseline/nback/{sub_id}/ses-baselineYear1Arm1/func/{sub_id}_ses-baselineYear1Arm1_task-nback_{run}_motion.tsv')
events = pd.read_table(f'/snl/abcd/raw-data/fmri/baseline/nback/{sub_id}/ses-baselineYear1Arm1/func/{sub_id}_ses-baselineYear1Arm1_task-nback_{run}_events.tsv')

# %%
t_r = 0.8
n_scans = len(timeseries_all)

frame_times = np.arange(n_scans) * t_r
frame_times

design_matrix = make_first_level_design_matrix(frame_times, events, hrf_model = None)
design_matrix = design_matrix.reset_index()


conditions = {}

cond_a = '2_back'
cond_b = '0_back'


# Find all col indices matching 2-back:
A = design_matrix.keys().str.contains(cond_a, regex=False).astype(int) # cast to 0-1
B = design_matrix.keys().str.contains(cond_b, regex=False).astype(int) # cast to 0-1

# %%
# Filter columns that start with 'string'
string_cols = design_matrix.filter(regex='^0_back')
A = string_cols.sum(axis=1)

string_cols = design_matrix.filter(regex='^2_back')
B = string_cols.sum(axis=1)

# %%
plt.figure(figsize=(15,5))
plt.plot(A, label='0_back')
plt.plot(B,label='2_back')
plt.legend()

# %%
plt.figure(figsize=(15,5))
for c in design_matrix.columns[1:9]:
    plt.plot(design_matrix[c], label=c)
    plt.legend()

# %%
taskA = timeseries_all[A.astype('bool').astype('bool'), :]
taskB = timeseries_all[B.astype('bool').astype('bool'), :]

# %%
Cov, DDC, Reg_DDC, nl_DDC, qc_flag = compute_ddc(taskA, 0.8, "c")
plt.figure(figsize=(20, 5))
plt.subplot(141)
plt.imshow(Cov)
plt.title("Cov")
plt.colorbar()
plt.subplot(142)
plt.imshow(DDC)
plt.title("DDC")
plt.colorbar()
plt.subplot(143)
plt.imshow(Reg_DDC)
plt.title("Reg_DDC")
plt.colorbar()

Cov, DDC, Reg_DDC, nl_DDC, qc_flag = compute_ddc(taskB, 0.8, "c")
plt.figure(figsize=(20, 5))
plt.subplot(141)
plt.imshow(Cov)
plt.title("Cov")
plt.colorbar()
plt.subplot(142)
plt.imshow(DDC)
plt.title("DDC")
plt.colorbar()
plt.subplot(143)
plt.imshow(Reg_DDC)
plt.title("Reg_DDC")
plt.colorbar()
# Out:
# Cov is rank deficient!
# Cov is rank deficient!

# %%
files[0][-10:]
# Out:
# 'run-01.csv'
