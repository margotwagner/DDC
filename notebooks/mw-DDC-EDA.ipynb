# %%
import sys
sys.path.insert(0, "../../../SynthSeg/scripts/postprocessing")
from Labels import Labels
labels = Labels().df

# %%
## One hemisphere FC 
#from FunctionalConnectivity import FunctionalConnectivity
#one_hemi_fc = FunctionalConnectivity(labels, n_roi=34, weights_file_name="filt_Delta L1H*.csv")

# %%
## Two hemisphere FC 
from FunctionalConnectivity import FunctionalConnectivity
two_hemi_fc = FunctionalConnectivity(labels, n_roi=68, weights_file_name="filt_Delta L2H*.csv")

# %%
'''
import sys
from Analyze_DDC import Analyze_DDC

# Automatically checks for normalcy using shapiro
analysis = Analyze_DDC(
    two_hemi_fc.control,
    two_hemi_fc.depress,
    ind=True,
    verbose=True
)
sig_connections = analysis.compare(plot=True)
'''
# Out:
# '\nimport sys\nfrom Analyze_DDC import Analyze_DDC\n\n# Automatically checks for normalcy using shapiro\nanalysis = Analyze_DDC(\n    two_hemi_fc.control,\n    two_hemi_fc.depress,\n    ind=True,\n    verbose=True\n)\nsig_connections = analysis.compare(plot=True)\n'

# %%
two_hemi_fc.plot_weights_across_states()

# %%
two_hemi_fc.plot_2()

# %%
two_hemi_fc.plot_3()

# %%
#two_hemi_fc.plot_4()

# %%
#two_hemi_fc.plot_5()

# %%
two_hemi_fc.plot_mean_weights("control")

# %%
two_hemi_fc.plot_mean_weights("depressed")

# %%
two_hemi_fc.plot_means()

# %%
#two_hemi_fc.plot_9()

# %%
#two_hemi_fc.plot_network_heatmap("DMN")

# %%
#two_hemi_fc.plot_network("DMN")

# %%
#two_hemi_fc.plot_network_heatmap("CEN")

# %%
#two_hemi_fc.plot_network("CEN")

# %%
#two_hemi_fc.plot_network_heatmap("SN")

# %%
#two_hemi_fc.plot_network("SN")

# %%
#two_hemi_fc.plot_network_connectivity("DMN", "control")

# %%
#two_hemi_fc.plot_network_connectivity("DMN", "depressed")

# %%
#two_hemi_fc.plot_network_connectivity("CEN", "control")

# %%
#two_hemi_fc.plot_network_connectivity("CEN", "depressed")

# %%
#two_hemi_fc.plot_network_connectivity("SN", "control")

# %%
#two_hemi_fc.plot_network_connectivity("SN", "depressed")

# %%
#two_hemi_fc.plot_connectivity("control")

# %%
#two_hemi_fc.plot_connectivity("depressed")

# %%
#view = two_hemi_fc.plot_interactive_connectivity("control")
#view
# Out:
# /home/mwagner/.local/lib/python3.9/site-packages/nilearn/plotting/js_plotting_utils.py:76: UserWarning: you have specified symmetric_cmap=False but the map contains negative values; setting symmetric_cmap to True
#   warnings.warn('you have specified symmetric_cmap=False '

# %%
cov = FunctionalConnectivity(labels, n_roi=68, weights_file_name="filt_Cov2H*.csv")

# %%
cov.plot_means()

# %%
fig=plt.figure(figsize=(10,10))
n=0
for i in range(100):
    ax = fig.add_subplot(10,10,n+1)
    plt.imshow(control_cov[i,:,:])
    plt.clim([0,1])

    plt.axis('off')
    n=n+1
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
cov.plot_weights_across_states()

# %%
Desikan_ROIs=['ctx-lh-bankssts', 'ctx-lh-caudalanteriorcingulate',
        'ctx-lh-caudalmiddlefrontal', 'ctx-lh-cuneus',
        'ctx-lh-entorhinal', 'ctx-lh-fusiform', 'ctx-lh-inferiorparietal',
        'ctx-lh-inferiortemporal', 'ctx-lh-isthmuscingulate',
        'ctx-lh-lateraloccipital', 'ctx-lh-lateralorbitofrontal',
        'ctx-lh-lingual', 'ctx-lh-medialorbitofrontal',
        'ctx-lh-middletemporal', 'ctx-lh-parahippocampal',
        'ctx-lh-paracentral', 'ctx-lh-parsopercularis',
        'ctx-lh-parsorbitalis', 'ctx-lh-parstriangularis',
        'ctx-lh-pericalcarine', 'ctx-lh-postcentral',
        'ctx-lh-posteriorcingulate', 'ctx-lh-precentral',
        'ctx-lh-precuneus', 'ctx-lh-rostralanteriorcingulate',
        'ctx-lh-rostralmiddlefrontal', 'ctx-lh-superiorfrontal',
        'ctx-lh-superiorparietal', 'ctx-lh-superiortemporal',
        'ctx-lh-supramarginal', 'ctx-lh-frontalpole',
        'ctx-lh-temporalpole', 'ctx-lh-transversetemporal',
        'ctx-lh-insula', 'ctx-rh-bankssts',
        'ctx-rh-caudalanteriorcingulate', 'ctx-rh-caudalmiddlefrontal',
        'ctx-rh-cuneus', 'ctx-rh-entorhinal', 'ctx-rh-fusiform',
        'ctx-rh-inferiorparietal', 'ctx-rh-inferiortemporal',
        'ctx-rh-isthmuscingulate', 'ctx-rh-lateraloccipital',
        'ctx-rh-lateralorbitofrontal', 'ctx-rh-lingual',
        'ctx-rh-medialorbitofrontal', 'ctx-rh-middletemporal',
        'ctx-rh-parahippocampal', 'ctx-rh-paracentral',
        'ctx-rh-parsopercularis', 'ctx-rh-parsorbitalis',
        'ctx-rh-parstriangularis', 'ctx-rh-pericalcarine',
        'ctx-rh-postcentral', 'ctx-rh-posteriorcingulate',
        'ctx-rh-precentral', 'ctx-rh-precuneus',
        'ctx-rh-rostralanteriorcingulate', 'ctx-rh-rostralmiddlefrontal',
        'ctx-rh-superiorfrontal', 'ctx-rh-superiorparietal',
        'ctx-rh-superiortemporal', 'ctx-rh-supramarginal',
        'ctx-rh-frontalpole', 'ctx-rh-temporalpole',
        'ctx-rh-transversetemporal', 'ctx-rh-insula']

# %%
len(Desikan_ROIs)
# Out:
# 68

# %% [markdown]
# medial prefrontal 25
# posterior cyngulate 21
# inferior parietal lobe 6
# precuneo 23
# lateral temporal cortex 31
#
# DMN=[25,21,6,23,31]

# %% [markdown]
# CEN=[1,6,25,33]
#
# SN
# anterior insula 33
# ventral anterior cingulate 23
# dorsal anterior cingulate 1
# operculum 16
# frontal pole 30
