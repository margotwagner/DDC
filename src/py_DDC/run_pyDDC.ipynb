# %%
import numpy as np
import pandas as pd
from numpy.linalg import inv
from scipy.stats import zscore

# %%
import Compute_DDC

# %%
from Compute_DDC import *

# %%
tsfile = '/nadata/cnl/abcd/data/imaging/fmri/rsfmri/interim/segmented/baseline/test1/sub-NDARINVZZZ2ALR6/filt_fMRI_segmented_sub-NDARINVZZZ2ALR6run-03.csv'
ts = np.loadtxt(tsfile, delimiter=',', dtype=float)

# %%
Cov, DDC, Reg_DDC, _ = compute_ddc(ts, 0.8, 'c')
# works better if ts is band pass filtered
# Reg DDC is needed when Cov is rank deficient or singular

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.subplot(131)
plt.imshow(Cov)
plt.title('Cov')
plt.colorbar()
plt.subplot(132)
plt.imshow(DDC)
plt.title('DDC')
plt.colorbar()
plt.subplot(133)
plt.imshow(Reg_DDC)
plt.title('Reg_DDC')
plt.colorbar()

# %%
Cov, DDC, Reg_DDC, _ = compute_ddc(ts, 0.8, 2)

# %%
plt.figure(figsize=(20,10))
plt.subplot(131)
plt.imshow(Cov)
plt.title('Cov')
plt.colorbar()
plt.subplot(132)
plt.imshow(DDC)
plt.title('DDC')
plt.colorbar()
plt.subplot(133)
plt.imshow(Reg_DDC)
plt.title('Reg_DDC')
plt.colorbar()
